# %%
import pandas as pd
import numpy as np

# %%
adf=pd.read_csv('Addresses.csv')

# %%
adf.head()
# Out:
#     ADDRESSID        CITY POSTALCODE            STREET  BUILDING COUNTRY  \
# 0  1000000034  West Nyack      10994     Settlers Lane    5027.0      US
# 1  1000000035   Fair Oaks      95628  Woodland Terrace    4467.0      US
# 2  1000000036        Dunn      28334     Layman Avenue    2250.0      US
# 3  1000000037     Chicago      60605  University Drive    4697.0      US
# 4  1000000038       Ocala      34471    Bagwell Avenue    1565.0      US
#
#   REGION  ADDRESSTYPE  VALIDITY_STARTDATE  VALIDITY_ENDDATE   LATITUDE  \
# 0   AMER            2            20000101          99991231  41.100057
# 1   AMER            2            20000101          99991231  38.638355
# 2   AMER            2            20000101          99991231  35.312013
# 3   AMER            2            20000101          99991231  41.874591
# 4   AMER            2            20000101          99991231  29.183977
#
#     LONGITUDE
# 0  -73.973562
# 1 -121.286683
# 2  -78.609950
# 3  -87.627303
# 4  -82.118413

# %%
#If Table show no values that means it does not have duplicated values

adf.loc[adf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ADDRESSID, CITY, POSTALCODE, STREET, BUILDING, COUNTRY, REGION, ADDRESSTYPE, VALIDITY_STARTDATE, VALIDITY_ENDDATE, LATITUDE, LONGITUDE]
# Index: []

# %%
bpdf=pd.read_csv('BusinessPartners.csv')

# %%
bpdf.loc[bpdf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PARTNERID, PARTNERROLE, EMAILADDRESS, PHONENUMBER, FAXNUMBER, WEBADDRESS, ADDRESSID, COMPANYNAME, LEGALFORM, CREATEDBY, CREATEDAT, CHANGEDBY, CHANGEDAT, CURRENCY]
# Index: []

# %%
import pandas as pd
import chardet

# Detect the encoding of the file
with open('Employees.csv', 'rb') as file:
    result = chardet.detect(file.read())
    encoding = result['encoding']
    print(f"Detected encoding: {encoding}")

# Read the CSV file with the detected encoding
edf = pd.read_csv('Employees.csv', encoding=encoding)

# Display the first few rows of the dataframe
print(edf.head())
# Out:
# Detected encoding: ISO-8859-1
#    EMPLOYEEID NAME_FIRST NAME_MIDDLE  NAME_LAST  NAME_INITIALS SEX LANGUAGE  \
# 0           1    Derrick           L     Magill            NaN   M        E
# 1           2    Philipp           T      Egger            NaN   M        E
# 2           3      Ellis           K  Robertson            NaN   M        E
# 3           4    William           M     Mussen            NaN   M        E
# 4           5      Javas         NaN      Hegde            NaN   M        E
#
#       PHONENUMBER                EMAILADDRESS LOGINNAME   ADDRESSID  \
# 0    630-374-0306   derrick.magill@itelo.info  derrickm  1000000001
# 1  09603 61 24 64    philipp.egger@itelo.info  philippm  1000000002
# 2   070 8691 2288  ellis.robertson@itelo.info    ellism  1000000003
# 3     026734 4556   william.mussen@itelo.info  williamm  1000000004
# 4     02224135120      javas.hegde@itelo.info    javasm  1000000005
#
# ...

# %%
edf.head()
# Out:
#    EMPLOYEEID NAME_FIRST NAME_MIDDLE  NAME_LAST  NAME_INITIALS SEX LANGUAGE  \
# 0           1    Derrick           L     Magill            NaN   M        E
# 1           2    Philipp           T      Egger            NaN   M        E
# 2           3      Ellis           K  Robertson            NaN   M        E
# 3           4    William           M     Mussen            NaN   M        E
# 4           5      Javas         NaN      Hegde            NaN   M        E
#
#       PHONENUMBER                EMAILADDRESS LOGINNAME   ADDRESSID  \
# 0    630-374-0306   derrick.magill@itelo.info  derrickm  1000000001
# 1  09603 61 24 64    philipp.egger@itelo.info  philippm  1000000002
# 2   070 8691 2288  ellis.robertson@itelo.info    ellism  1000000003
# 3     026734 4556   william.mussen@itelo.info  williamm  1000000004
# 4     02224135120      javas.hegde@itelo.info    javasm  1000000005
#
#    VALIDITY_STARTDATE  VALIDITY_ENDDATE  Unnamed: 13  Unnamed: 14  \
# ...

# %%
edf.loc[edf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [EMPLOYEEID, NAME_FIRST, NAME_MIDDLE, NAME_LAST, SEX, LANGUAGE, PHONENUMBER, EMAILADDRESS, LOGINNAME, ADDRESSID, VALIDITY_STARTDATE, VALIDITY_ENDDATE]
# Index: []

# %%
edf=edf.dropna(axis=1, how='all')

# %%
edf.head()
# Out:
#    EMPLOYEEID NAME_FIRST NAME_MIDDLE  NAME_LAST SEX LANGUAGE     PHONENUMBER  \
# 0           1    Derrick           L     Magill   M        E    630-374-0306
# 1           2    Philipp           T      Egger   M        E  09603 61 24 64
# 2           3      Ellis           K  Robertson   M        E   070 8691 2288
# 3           4    William           M     Mussen   M        E     026734 4556
# 4           5      Javas         NaN      Hegde   M        E     02224135120
#
#                  EMAILADDRESS LOGINNAME   ADDRESSID  VALIDITY_STARTDATE  \
# 0   derrick.magill@itelo.info  derrickm  1000000001            20000101
# 1    philipp.egger@itelo.info  philippm  1000000002            20000101
# 2  ellis.robertson@itelo.info    ellism  1000000003            20000101
# 3   william.mussen@itelo.info  williamm  1000000004            20000101
# 4      javas.hegde@itelo.info    javasm  1000000005            20000101
#
#    VALIDITY_ENDDATE
# 0          99991231
# 1          99991231
# ...

# %%
pcdf=pd.read_csv('ProductCategories.csv')

# %%
pcdf['CREATEDAT']=pd.to_datetime(pcdf['CREATEDAT'])

# %%
pcdf.head()
# Out:
#   PRODCATEGORYID  CREATEDBY  CREATEDAT
# 0             RO         12   20181003
# 1             BX          4   20181003
# 2             CC          7   20181003
# 3             MB         11   20181003
# 4             RC          9   20181003

# %%
pcdf['CREATEDAT']= pd.to_datetime(pcdf['CREATEDAT'] ,format="%y-%m-%d")

# %%
pcdf.head()
# Out:
#   PRODCATEGORYID  CREATEDBY                     CREATEDAT
# 0             RO         12 1970-01-01 00:00:00.020181003
# 1             BX          4 1970-01-01 00:00:00.020181003
# 2             CC          7 1970-01-01 00:00:00.020181003
# 3             MB         11 1970-01-01 00:00:00.020181003
# 4             RC          9 1970-01-01 00:00:00.020181003

# %%
pcdf['CREATEDAT']=pcdf['CREATEDAT'].dt.date

# %%
pcdf.head()
# Out:
#   PRODCATEGORYID  CREATEDBY   CREATEDAT
# 0             RO         12  1970-01-01
# 1             BX          4  1970-01-01
# 2             CC          7  1970-01-01
# 3             MB         11  1970-01-01
# 4             RC          9  1970-01-01

# %%
pcdf.to_csv('ProductCategories.csv', index=False)

# %%
pcdf.head()
# Out:
#   PRODCATEGORYID  CREATEDBY   CREATEDAT
# 0             RO         12  1970-01-01
# 1             BX          4  1970-01-01
# 2             CC          7  1970-01-01
# 3             MB         11  1970-01-01
# 4             RC          9  1970-01-01

# %%
pcdf.loc[pcdf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PRODCATEGORYID, CREATEDBY, CREATEDAT]
# Index: []

# %%
pctdf=pd.read_csv('ProductCategoryText.csv')

# %%
pctdf.loc[pctdf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PRODCATEGORYID, LANGUAGE, SHORT_DESCR, MEDIUM_DESCR, LONG_DESCR]
# Index: []

# %%
pctdf=pctdf.dropna(axis=1, how='all')

# %%
pctdf.head()
# Out:
#   PRODCATEGORYID LANGUAGE       SHORT_DESCR
# 0             RO       EN         Road Bike
# 1             BX       EN               BMX
# 2             CC       EN  Cyclo-cross Bike
# 3             MB       EN     Mountain Bike
# 4             RC       EN       Racing Bike

# %%
pctdf.to_csv('ProductCategoryText.csv', index=False)

# %%
ptdf=pd.read_csv('ProductTexts.csv')

# %%
ptdf.head()
# Out:
#   PRODUCTID LANGUAGE       SHORT_DESCR MEDIUM_DESCR  LONG_DESCR
# 0   RO-1001       EN        Roady 1001          NaN         NaN
# 1   RO-1002       EN        Roady 1002          NaN         NaN
# 2   RO-1003       EN        Roady 1003          NaN         NaN
# 3   BX-1011       EN  BMX Vintage 1011          NaN         NaN
# 4   BX-1012       EN     BMX Jump 1012          NaN         NaN

# %%
ptdf=ptdf.dropna(axis=1, how='all')

# %%
ptdf.head()
# Out:
#   PRODUCTID LANGUAGE       SHORT_DESCR MEDIUM_DESCR
# 0   RO-1001       EN        Roady 1001          NaN
# 1   RO-1002       EN        Roady 1002          NaN
# 2   RO-1003       EN        Roady 1003          NaN
# 3   BX-1011       EN  BMX Vintage 1011          NaN
# 4   BX-1012       EN     BMX Jump 1012          NaN

# %%
ptdf.loc[ptdf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PRODUCTID, LANGUAGE, SHORT_DESCR, MEDIUM_DESCR]
# Index: []

# %%
ptdf.to_csv('ProductTexts.csv',index=False)

# %%
soidf=pd.read_csv('SalesOrderItems.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 soidf=pd.read_csv('SalesOrderItems.csv', index=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
soidf.head()
# Out:
#    SALESORDERID  SALESORDERITEM PRODUCTID NOTEID CURRENCY  GROSSAMOUNT  \
# 0     500000000              10   MB-1034             USD         2499
# 1     500000000              20   CB-1161             USD          399
# 2     500000001              10   HB-1175             USD          899
# 3     500000001              20   RC-1056             USD         2499
# 4     500000001              30   CC-1021             USD         1144
#
#    NETAMOUNT  TAXAMOUNT ITEMATPSTATUS  OPITEMPOS  QUANTITY QUANTITYUNIT  \
# 0   2186.625    312.375             I        NaN         4           EA
# 1    349.125     49.875             I        NaN         9           EA
# 2    786.625    112.375             I        NaN         2           EA
# 3   2186.625    312.375             I        NaN         2           EA
# 4   1001.000    143.000             I        NaN         3           EA
#
#    DELIVERYDATE
# 0      20180311
# 1      20180311
# 2      20180228
# 3      20180228
# 4      20180228

# %%
soidf=soidf.dropna(axis=1, how='all')

# %%
soidf.head()
# Out:
#    Unnamed: 0  SALESORDERID  SALESORDERITEM PRODUCTID NOTEID CURRENCY  \
# 0           0     500000000              10   MB-1034             USD
# 1           1     500000000              20   CB-1161             USD
# 2           2     500000001              10   HB-1175             USD
# 3           3     500000001              20   RC-1056             USD
# 4           4     500000001              30   CC-1021             USD
#
#    GROSSAMOUNT  NETAMOUNT  TAXAMOUNT ITEMATPSTATUS  QUANTITY QUANTITYUNIT  \
# 0         2499   2186.625    312.375             I         4           EA
# 1          399    349.125     49.875             I         9           EA
# 2          899    786.625    112.375             I         2           EA
# 3         2499   2186.625    312.375             I         2           EA
# 4         1144   1001.000    143.000             I         3           EA
#
#    DELIVERYDATE
# 0      20180311
# 1      20180311
# 2      20180228
# 3      20180228
# ...

# %%
soidf.loc[soidf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, SALESORDERID, SALESORDERITEM, PRODUCTID, NOTEID, CURRENCY, GROSSAMOUNT, NETAMOUNT, TAXAMOUNT, ITEMATPSTATUS, QUANTITY, QUANTITYUNIT, DELIVERYDATE]
# Index: []

# %%
if 'Unnamed: 0' in soidf.columns:
    soidf.drop(columns=['Unnamed: 0'], inplace=True)

# %%
soidf.head()
# Out:
#    SALESORDERID  SALESORDERITEM PRODUCTID NOTEID CURRENCY  GROSSAMOUNT  \
# 0     500000000              10   MB-1034             USD         2499
# 1     500000000              20   CB-1161             USD          399
# 2     500000001              10   HB-1175             USD          899
# 3     500000001              20   RC-1056             USD         2499
# 4     500000001              30   CC-1021             USD         1144
#
#    NETAMOUNT  TAXAMOUNT ITEMATPSTATUS  QUANTITY QUANTITYUNIT  DELIVERYDATE
# 0   2186.625    312.375             I         4           EA      20180311
# 1    349.125     49.875             I         9           EA      20180311
# 2    786.625    112.375             I         2           EA      20180228
# 3   2186.625    312.375             I         2           EA      20180228
# 4   1001.000    143.000             I         3           EA      20180228

# %%
soidf.to_csv('SalesOrderItems.csv', index=False)

# %%
soidf.head()
# Out:
#    SALESORDERID  SALESORDERITEM PRODUCTID NOTEID CURRENCY  GROSSAMOUNT  \
# 0     500000000              10   MB-1034             USD         2499
# 1     500000000              20   CB-1161             USD          399
# 2     500000001              10   HB-1175             USD          899
# 3     500000001              20   RC-1056             USD         2499
# 4     500000001              30   CC-1021             USD         1144
#
#    NETAMOUNT  TAXAMOUNT ITEMATPSTATUS  QUANTITY QUANTITYUNIT  DELIVERYDATE
# 0   2186.625    312.375             I         4           EA      20180311
# 1    349.125     49.875             I         9           EA      20180311
# 2    786.625    112.375             I         2           EA      20180228
# 3   2186.625    312.375             I         2           EA      20180228
# 4   1001.000    143.000             I         3           EA      20180228

# %%
soidf.replace('', np.nan, inplace=True)

# %%
soidf.head()
# Out:
#    SALESORDERID  SALESORDERITEM PRODUCTID NOTEID CURRENCY  GROSSAMOUNT  \
# 0     500000000              10   MB-1034             USD         2499
# 1     500000000              20   CB-1161             USD          399
# 2     500000001              10   HB-1175             USD          899
# 3     500000001              20   RC-1056             USD         2499
# 4     500000001              30   CC-1021             USD         1144
#
#    NETAMOUNT  TAXAMOUNT ITEMATPSTATUS  QUANTITY QUANTITYUNIT  DELIVERYDATE
# 0   2186.625    312.375             I         4           EA      20180311
# 1    349.125     49.875             I         9           EA      20180311
# 2    786.625    112.375             I         2           EA      20180228
# 3   2186.625    312.375             I         2           EA      20180228
# 4   1001.000    143.000             I         3           EA      20180228

# %%
soidf['DELIVERYDATE']= pd.to_datetime(soidf['DELIVERYDATE'])

# %%
soidf['DELIVERYDATE']=soidf['DELIVERYDATE'].dt.date

# %%
soidf.dtypes
# Out:
# SALESORDERID        int64
# SALESORDERITEM      int64
# PRODUCTID          object
# NOTEID             object
# CURRENCY           object
# GROSSAMOUNT         int64
# NETAMOUNT         float64
# TAXAMOUNT         float64
# ITEMATPSTATUS      object
# QUANTITY            int64
# QUANTITYUNIT       object
# DELIVERYDATE       object
# dtype: object

# %%
soidf.to_csv('SalesOrderItems.csv',index=False)

# %%
ptdf.head()
# Out:
#   PRODUCTID LANGUAGE       SHORT_DESCR MEDIUM_DESCR
# 0   RO-1001       EN        Roady 1001          NaN
# 1   RO-1002       EN        Roady 1002          NaN
# 2   RO-1003       EN        Roady 1003          NaN
# 3   BX-1011       EN  BMX Vintage 1011          NaN
# 4   BX-1012       EN     BMX Jump 1012          NaN

# %%
pdf=pd.read_csv('Products.csv')

# %%
pdf.head()
# Out:
#   PRODUCTID TYPECODE PRODCATEGORYID  CREATEDBY  CREATEDAT  CHANGEDBY  \
# 0   RO-1001       PR             RO          9   20181003          9
# 1   RO-1002       PR             RO          9   20181003          9
# 2   RO-1003       PR             RO         12   20181003         12
# 3   BX-1011       PR             BX          9   20181003          9
# 4   BX-1012       PR             BX          6   20181003          6
#
#    CHANGEDAT  SUPPLIER_PARTNERID  TAXTARIFFCODE QUANTITYUNIT  WEIGHTMEASURE  \
# 0   20181003           100000000              1           EA            7.7
# 1   20181003           100000001              1           EA            8.0
# 2   20181003           100000002              1           EA            9.1
# 3   20181003           100000003              1           EA           11.1
# 4   20181003           100000004              1           EA           12.0
#
#   WEIGHTUNIT CURRENCY  PRICE  WIDTH  DEPTH  HEIGHT  DIMENSIONUNIT  \
# ...

# %%
pdf.dtypes
# Out:
# PRODUCTID              object
# TYPECODE               object
# PRODCATEGORYID         object
# CREATEDBY               int64
# CREATEDAT               int64
# CHANGEDBY               int64
# CHANGEDAT               int64
# SUPPLIER_PARTNERID      int64
# TAXTARIFFCODE           int64
# QUANTITYUNIT           object
# WEIGHTMEASURE         float64
# WEIGHTUNIT             object
# CURRENCY               object
# PRICE                   int64
# WIDTH                 float64
# DEPTH                 float64
# HEIGHT                float64
# DIMENSIONUNIT         float64
# PRODUCTPICURL         float64
# dtype: object

# %%
pdf=pdf.dropna(axis=1,how='all')

# %%
pdf.shape
# Out:
# (42, 14)

# %%
pdf.describe()
# Out:
#        CREATEDBY   CREATEDAT  CHANGEDBY   CHANGEDAT  SUPPLIER_PARTNERID  \
# count  42.000000        42.0  42.000000        42.0        4.200000e+01
# mean    7.857143  20181003.0   7.857143  20181003.0        1.000000e+08
# std     4.087885         0.0   4.087885         0.0        1.226784e+01
# min     1.000000  20181003.0   1.000000  20181003.0        1.000000e+08
# 25%     5.000000  20181003.0   5.000000  20181003.0        1.000000e+08
# 50%     7.500000  20181003.0   7.500000  20181003.0        1.000000e+08
# 75%    11.750000  20181003.0  11.750000  20181003.0        1.000000e+08
# max    14.000000  20181003.0  14.000000  20181003.0        1.000000e+08
#
#        TAXTARIFFCODE  WEIGHTMEASURE        PRICE
# count           42.0      42.000000    42.000000
# mean             1.0      12.614286  1873.857143
# std              0.0       4.342449  1799.797476
# min              1.0       6.900000   249.000000
# 25%              1.0       8.225000   649.000000
# ...

# %%
pdf.head(1)
# Out:
#   PRODUCTID TYPECODE PRODCATEGORYID  CREATEDBY                     CREATEDAT  \
# 0   RO-1001       PR             RO          9 1970-01-01 00:00:00.020181003
#
#    CHANGEDBY                     CHANGEDAT  SUPPLIER_PARTNERID  TAXTARIFFCODE  \
# 0          9 1970-01-01 00:00:00.020181003           100000000              1
#
#   QUANTITYUNIT  WEIGHTMEASURE WEIGHTUNIT CURRENCY  PRICE
# 0           EA            7.7         KG      USD    525

# %%
    pdf['CHANGEDAT']=pdf['CHANGEDAT'].dt.date
# Out:
# C:\Users\Anwar Khan\AppData\Local\Temp\ipykernel_13212\3074139093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdf['CHANGEDAT']=pdf['CHANGEDAT'].dt.date

# %%
pdf.head(1)
# Out:
#   PRODUCTID TYPECODE PRODCATEGORYID  CREATEDBY   CREATEDAT  CHANGEDBY  \
# 0   RO-1001       PR             RO          9  1970-01-01          9
#
#     CHANGEDAT  SUPPLIER_PARTNERID  TAXTARIFFCODE QUANTITYUNIT  WEIGHTMEASURE  \
# 0  1970-01-01           100000000              1           EA            7.7
#
#   WEIGHTUNIT CURRENCY  PRICE
# 0         KG      USD    525

# %%
pdf.to_csv('Products.csv',index=False)

# %%
pdf.dtypes
# Out:
# PRODUCTID              object
# TYPECODE               object
# PRODCATEGORYID         object
# CREATEDBY               int64
# CREATEDAT              object
# CHANGEDBY               int64
# CHANGEDAT              object
# SUPPLIER_PARTNERID      int64
# TAXTARIFFCODE           int64
# QUANTITYUNIT           object
# WEIGHTMEASURE         float64
# WEIGHTUNIT             object
# CURRENCY               object
# PRICE                   int64
# dtype: object

# %%
pdf.head(1)
# Out:
#   PRODUCTID TYPECODE PRODCATEGORYID  CREATEDBY   CREATEDAT  CHANGEDBY  \
# 0   RO-1001       PR             RO          9  1970-01-01          9
#
#     CHANGEDAT  SUPPLIER_PARTNERID  TAXTARIFFCODE QUANTITYUNIT  WEIGHTMEASURE  \
# 0  1970-01-01           100000000              1           EA            7.7
#
#   WEIGHTUNIT CURRENCY  PRICE
# 0         KG      USD    525
